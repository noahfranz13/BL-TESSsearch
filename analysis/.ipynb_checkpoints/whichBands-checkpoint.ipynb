# %%
import numpy as np
import pandas as pd
import pymysql
import os

# %%
# Query SQL Table

BLclient = pymysql.connect(host=os.environ['GCP_IP'],user=os.environ['GCP_USR'],
                              password=os.environ['GCP_PASS'],database="FileTracking")

BLquery = """
SELECT *
FROM `infiles`
"""

fileinfo = pd.read_sql(BLquery, BLclient)

# %%
def whichBand(filenames):
    
    from blimpy import Waterfall
    from blimpy.io.fil_reader import FilReader
    
    band = []
    for filename in filenames:
        wf = Waterfall(filename, load_data=False)
        hdr = FilReader.read_header(wf)
        #print(f'Finding Band for {filename}')
        
        if filename.find('spliced') != -1:
            maxf = hdr['fch1']
            tocheck = (maxf + (0.5 * hdr['foff'] * hdr['nchans'])) * 10**-3
            
            if tocheck > 1.10 and tocheck < 1.90:
                band.append('L-Band')
            elif tocheck > 1.80 and tocheck < 2.80:
                band.append('S-Band')
            elif tocheck > 4.00 and tocheck < 7.80:
                band.append('C-Band')
            elif tocheck > 7.80 and tocheck < 11.20:
                band.append('X-Band')
            else:
                band.append('UH OH')
                
        else:
            maxf = hdr['fch1'] * 10**-3
            minf = maxf - np.abs(hdr['foff']*hdr['nchans'])*10**-3
            
            if minf > 1.10 and maxf < 1.90:
                band.append('L-Band')
            elif minf > 1.80 and maxf < 2.80:
                band.append('S-Band')
            elif minf > 4.00 and maxf < 7.80:
                band.append('C-Band')
            elif minf > 7.80 and maxf < 11.20:
                band.append('X-Band')
            else:
                band.append('IGNORE')
            
    return band

# %%
band = whichBand(fileinfo.filepath.to_numpy())
fileinfo['band'] = band
fileinfo
# Out:
#       row_num   target_name  obs_time on_off           toi  \
# 0           0  TIC344926234   58811.6     ON  TIC344926234
# 1           1      HIP49458   58811.6    OFF  TIC344926234
# 2           2  TIC344926234   58811.6     ON  TIC344926234
# 3           3      HIP49824   58811.6    OFF  TIC344926234
# 4           4  TIC344926234   58811.6     ON  TIC344926234
# ...       ...           ...       ...    ...           ...
# 6333     6333      HIP31574   59365.9    OFF  TIC438490744
# 6334     6334      HIP31574   59365.9    OFF  TIC438490744
# 6335     6335      HIP31574   59365.9    OFF  TIC438490744
# 6336     6336      HIP31574   59365.9    OFF  TIC438490744
# 6337     6337      HIP31574   59365.9    OFF  TIC438490744
#
#                                                filename  \
# 0     spliced_blc0001020304050607_guppi_58811_53010_...
# 1     spliced_blc0001020304050607_guppi_58811_53324_...
# 2     spliced_blc0001020304050607_guppi_58811_53638_...
# 3     spliced_blc0001020304050607_guppi_58811_53957_...
# 4     spliced_blc0001020304050607_guppi_58811_54276_...
# ...                                                 ...
# 6333  blc45_guppi_59365_79339_HIP31574_0113.rawspec....
# 6334  blc63_guppi_59365_79339_HIP31574_0113.rawspec....
# 6335  blc75_guppi_59365_79339_HIP31574_0113.rawspec....
# 6336  blc46_guppi_59365_79339_HIP31574_0113.rawspec....
# 6337  blc41_guppi_59365_79339_HIP31574_0113.rawspec....
#
#                                                filepath     splice turboSETI  \
# 0     /mnt_bls8/datax3/collate/AGBT19B_999_114/splic...    spliced      TRUE
# 1     /mnt_bls8/datax3/collate/AGBT19B_999_114/splic...    spliced      TRUE
# 2     /mnt_bls8/datax3/collate/AGBT19B_999_114/splic...    spliced      TRUE
# 3     /mnt_bls8/datax3/collate/AGBT19B_999_114/splic...    spliced      TRUE
# 4     /mnt_bls8/datax3/collate/AGBT19B_999_114/splic...    spliced      TRUE
# ...                                                 ...        ...       ...
# 6333  /mnt_blc45/datax/dibas/AGBT21A_996_41/GUPPI/BL...  unspliced     FALSE
# 6334  /mnt_blc63/datax/dibas/AGBT21A_996_41/GUPPI/BL...  unspliced     FALSE
# 6335  /mnt_blc75/datax/dibas/AGBT21A_996_41/GUPPI/BL...  unspliced     FALSE
# 6336  /mnt_blc46/datax/dibas/AGBT21A_996_41/GUPPI/BL...  unspliced     FALSE
# 6337  /mnt_blc41/datax/dibas/AGBT21A_996_41/GUPPI/BL...  unspliced     FALSE
#
#       runtime                                            outpath    band
# 0     38333.4  /datax/scratch/noahf/turboSETI-outFiles/TOI-TI...  S-Band
# 1     33063.7  /datax/scratch/noahf/turboSETI-outFiles/TOI-TI...  S-Band
# 2     14296.4  /datax/scratch/noahf/turboSETI-outFiles/TOI-TI...  S-Band
# 3     17835.3  /datax/scratch/noahf/turboSETI-outFiles/TOI-TI...  S-Band
# 4     49185.6  /datax/scratch/noahf/turboSETI-outFiles/TOI-TI...  S-Band
# ...       ...                                                ...     ...
# 6333      0.0                                                 \r  C-Band
# 6334      0.0                                                 \r  C-Band
# 6335      0.0                                                 \r  IGNORE
# 6336      0.0                                                 \r  C-Band
# 6337      0.0                                                     X-Band
#
# [6338 rows x 12 columns]

# %%
fileinfo.outpath = fileinfo.outpath.str.strip('\r')
fileinfo.to_csv('turboSETI-fileinfo-wBandInfo.csv')

# %%
# Are targets observed at more than one band?

toiband = []
for toi in fileinfo.toi.unique():
    
    wheretoi = fileinfo.toi == toi
    
    bands = fileinfo.band[wheretoi & (fileinfo.band != 'IGNORE')].unique()
    
    toiband.append([toi, bands])
    
toiband
# Out:
# [['TIC344926234', array(['S-Band', 'C-Band'], dtype=object)],
#  ['TIC365781372', array(['X-Band', 'IGNORE', 'C-Band'], dtype=object)],
#  ['TIC375542276', array(['IGNORE', 'S-Band', 'L-Band'], dtype=object)],
#  ['TIC459942762', array(['X-Band'], dtype=object)],
#  ['TIC280437559', array(['X-Band'], dtype=object)],
#  ['TIC425206121', array(['IGNORE', 'L-Band', 'S-Band'], dtype=object)],
#  ['TIC178367144', array(['S-Band', 'L-Band', 'IGNORE'], dtype=object)],
#  ['TIC121338379', array(['S-Band', 'L-Band', 'IGNORE'], dtype=object)],
#  ['TIC73104318', array(['X-Band'], dtype=object)],
#  ['TIC285674856', array(['X-Band'], dtype=object)],
#  ['TIC78154865', array(['S-Band', 'L-Band', 'IGNORE'], dtype=object)],
#  ['TIC286561122', array(['C-Band', 'IGNORE', 'X-Band'], dtype=object)],
#  ['TIC365683032',
#   array(['S-Band', 'X-Band', 'IGNORE', 'C-Band'], dtype=object)],
#  ['TIC348673213', array(['C-Band', 'X-Band', 'IGNORE'], dtype=object)],
#  ['TIC312862941', array(['C-Band', 'IGNORE', 'X-Band'], dtype=object)],
#  ['TIC422756130', array(['L-Band', 'S-Band', 'IGNORE'], dtype=object)],
#  ['TIC44631965', array(['IGNORE', 'C-Band', 'X-Band'], dtype=object)],
#  ['TIC147950620', array(['C-Band'], dtype=object)],
#  ['TIC311035838', array(['IGNORE', 'S-Band', 'L-Band'], dtype=object)],
#  ['TIC241076290', array(['S-Band', 'IGNORE', 'L-Band'], dtype=object)],
#  ['TIC26433869', array(['X-Band', 'C-Band', 'IGNORE'], dtype=object)],
#  ['TIC327011842', array(['X-Band', 'IGNORE', 'C-Band'], dtype=object)],
#  ['TIC241040309', array(['X-Band', 'IGNORE', 'C-Band'], dtype=object)],
#  ['TIC457138169', array(['C-Band', 'IGNORE', 'X-Band'], dtype=object)],
#  ['TIC142090065', array(['X-Band', 'IGNORE', 'C-Band'], dtype=object)],
#  ['TIC270468559', array(['C-Band', 'IGNORE', 'X-Band'], dtype=object)],
#  ['TIC137881699', array(['X-Band', 'IGNORE', 'C-Band'], dtype=object)],
#  ['TIC368536386', array(['C-Band', 'IGNORE', 'X-Band'], dtype=object)],
#  ['TIC353367071', array(['C-Band', 'X-Band', 'IGNORE'], dtype=object)],
#  ['TIC389182138', array(['C-Band', 'X-Band', 'IGNORE'], dtype=object)],
#  ['TIC138017750', array(['S-Band', 'L-Band', 'IGNORE'], dtype=object)],
#  ['TIC376637093',
#   array(['X-Band', 'C-Band', 'IGNORE', 'L-Band', 'S-Band'], dtype=object)],
#  ['TIC376682699', array(['X-Band', 'IGNORE', 'C-Band'], dtype=object)],
#  ['TIC191284318', array(['X-Band', 'C-Band', 'IGNORE'], dtype=object)],
#  ['TIC327579226', array(['X-Band', 'IGNORE', 'C-Band'], dtype=object)],
#  ['TIC292321872', array(['L-Band', 'IGNORE', 'S-Band'], dtype=object)],
#  ['TIC409183335', array(['L-Band', 'IGNORE', 'S-Band'], dtype=object)],
#  ['TIC235905185', array(['X-Band', 'IGNORE', 'C-Band'], dtype=object)],
#  ['TIC15863518', array(['X-Band', 'IGNORE', 'C-Band'], dtype=object)],
#  ['TIC371673488', array(['X-Band', 'C-Band', 'IGNORE'], dtype=object)],
#  ['TIC341815767', array(['X-Band', 'IGNORE', 'C-Band'], dtype=object)],
#  ['TIC358631536', array(['S-Band', 'L-Band', 'IGNORE'], dtype=object)],
#  ['TIC274942910', array(['S-Band', 'IGNORE', 'L-Band'], dtype=object)],
#  ['TIC233720539', array(['X-Band', 'IGNORE', 'C-Band'], dtype=object)],
#  ['TIC38686737', array(['X-Band', 'IGNORE', 'C-Band'], dtype=object)],
#  ['TIC117979455', array(['IGNORE', 'S-Band', 'L-Band'], dtype=object)],
#  ['TIC468880077', array(['C-Band', 'X-Band', 'IGNORE'], dtype=object)],
#  ['TIC154741689', array(['C-Band'], dtype=object)],
#  ['TIC427730490', array(['X-Band', 'IGNORE', 'C-Band'], dtype=object)],
#  ['TIC321688498', array(['X-Band', 'IGNORE', 'C-Band'], dtype=object)],
#  ['TIC393911494', array(['IGNORE', 'S-Band', 'L-Band'], dtype=object)],
#  ['TIC138168780', array(['S-Band', 'L-Band', 'IGNORE'], dtype=object)],
#  ['TIC328167090', array(['L-Band', 'S-Band', 'IGNORE'], dtype=object)],
#  ['TIC285542903', array(['C-Band', 'IGNORE', 'X-Band'], dtype=object)],
#  ['TIC438490744', array(['C-Band', 'IGNORE', 'X-Band'], dtype=object)]]
